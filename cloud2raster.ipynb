# %%
from osgeo import gdal
from matplotlib import pyplot as plt
import numpy as np

ds = gdal.Open('D:/UCL_Study/A-postgraduate research/raster/field1_clip.tif')
ds_array = ds.ReadAsArray()
print(ds_array.shape)
# Out:
# (151, 152)

# %%
band1 = ds.GetRasterBand(1)
band1_array = band1.ReadAsArray()
print(band1_array.shape)
# Out:
# (151, 152)

# %%
plt.imshow(band1_array)

# %%
np.savetxt('field6.csv',band1_array,delimiter=',')
